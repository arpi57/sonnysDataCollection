# %%
import pandas as pd

# %%
df = pd.read_csv("Car_Wash_Advisory_Companies.csv")

# %%
a = df['Company Name'].tolist()

# %%
type(a)
# Out:
# list

# %%
a[:176]
# Out:
# ['Whistle Express Car Wash',
#  'Mister Car Wash',
#  'Tidal Wave Auto Spa',
#  'Quick Quack Express Car Wash',
#  'Club Car Wash',
#  'Tommy�s Express Car Wash',
#  'Spotless Brands',
#  'GO Car Wash',
#  'Mammoth Holdings LLC',
#  'WhiteWater Express Car Wash',
#  'ModWash',
#  'Express Wash Concepts',
#  'Super Star Car Wash',
#  'Autobell Car Wash',
#  'LUV Car Wash',
#  'Summit Wash Holdings',
#  'True Blue Car Wash',
#  'Splash Car Wash',
#  'Caliber Car Wash',
#  'BlueWave Express Car Wash',
#  'El Car Wash',
#  'Splash in ECO Car Wash',
#  'Golden Nozzle Car Wash',
#  'Champion Xpress Carwash',
#  'Crew Carwash',
#  "Sam's Xpress Car Wash",
#  'Jax Kar Wash',
#  'Terrible Herbst',
#  "Big Dan's Car Wash",
#  'Mr. Clean Car Wash',
#  'Raceway Express Car Wash',
#  'Sparkling Image Car Wash',
#  "Wash N' Roll",
#  "Rich's Car Wash",
#  "Mike's Car Wash",
#  'Surf Thru Express Car Wash',
#  'Watershed Carwash',
#  'WetGo Car Wash',
#  'Delta Sonic',
#  'The Wash Tub',
#  'Gas N Wash',
#  'Hurricane Express Wash',
#  'Brown Bear Car Wash',
#  'Waterway Carwash',
#  'Hoffman Car Wash',
#  'Quick N Clean',
#  'ClearWater Express Wash',
#  'Thoroughbred Express Auto Wash',
#  'Trademark Car Wash',
#  'Rocket Carwash',
#  'Soapy Joe�s Car Wash',
#  'Wash Masters Car Wash',
#  'Washville Car Wash',
#  'Fast 5 Xpress Car Wash',
#  'Glide XPRESS Car Wash',
#  'Prestige Car Wash',
#  'Ultra Clean Express',
#  'Flagstop Car Wash',
#  'Mighty Wash',
#  'Mr. Magic Car Wash',
#  'ScrubaDub Auto Wash Centers',
#  'Splash Car Wash & Oil Change',
#  "Woodie's Wash Shack",
#  'WOW Carwash',
#  'Carnation Auto Spa',
#  'Dirty Dog�s Car Wash',
#  'Tagg-N-Go',
#  'Drive & Shine Car Wash',
#  'Flash Car Wash',
#  'Sgt. Clean�s Car Wash',
#  'TruShine Car Wash',
#  'Francis & Sons Car Wash',
#  "Fuller's Car Wash",
#  'Shiny Shell Car Wash',
#  'Washman Car Washes',
#  'Bubble Down Car Wash',
#  'Elephant Super Car Wash',
#  'Kaady Car Wash',
#  "Ronny's Car Wash",
#  'Big Peach Car Wash',
#  'Bliss Car Wash',
#  'Buddy Bear Car Wash',
#  "Fast Eddie's Car Wash & Oil Change",
#  'Gate Express Car Wash',
#  'Zax Auto Wash',
#  "Haffner's",
#  'Rainforest Carwash & Oil Change',
#  'Shammy Shine Car Washes',
#  'Car Spa',
#  'Mach-1 Express Wash',
#  'Ridi Stores',
#  'Rocky Mountain Car Wash',
#  'Breeze Thru Car Wash',
#  'Carriage House Car Wash',
#  'EDGE Express Car Wash',
#  'Metro Express Car Wash',
#  'Pelican Pointe Car Wash',
#  'The Auto Spa',
#  'Valet Auto Wash',
#  'All American Car Wash',
#  'Charlie�s Car Wash',
#  'iShine Express Car Wash & Detail',
#  'Jacksons',
#  'Speedy Stop Car Wash',
#  'Team Car Wash',
#  'Wash-Rite Express Car Wash',
#  'WashU Car Wash',
#  'White Horse Auto Wash',
#  'Fast Splash Car Wash',
#  'Hang 10 Car Wash',
#  'Raindrop Car Wash',
#  'RocketFast Car Wash',
#  'Super Clean Car Wash',
#  'Time To Shine Car Wash',
#  'WashX Car Wash',
#  'Xtreme Auto Wash',
#  '7 Flags Car Wash',
#  'Cheetah Clean Auto Wash',
#  "Ducky's Car Wash",
#  'Groove Car Wash',
#  'Mr Wash Car Wash',
#  'Red Carpet Car Wash',
#  'Scrub-a-Dub',
#  'Shine Time Super Wash',
#  'Tsunami Express',
#  'Wash Factory Car Wash',
#  'Xpress Car Wash',
#  'Blue Penguin Car Wash',
#  'BriteworX Car Washery',
#  'Clean Sweep Car Wash',
#  'Cloud 10 Smartwash',
#  'Everclean Car Wash',
#  'Scenic Suds Car Wash',
#  'Scrubby�s Car Wash',
#  'Skweeky Kleen Car Wash',
#  'SpeedWash Car Wash',
#  'Suds Deluxe Car Wash',
#  'WashGuys Car Wash',
#  'Auto Spa Car Wash (WA)',
#  'Benny�s Car Wash',
#  'Driven Car Wash',
#  'Fabulous Freddy�s Car Wash',
#  'Jet Splash Car Wash',
#  'Radiant Express Car Wash',
#  'Velocity Car Wash',
#  'Auto Spa LA',
#  'Clearwave Car Wash',
#  'Ocean Blue Car Wash',
#  'Snap Clean Car Wash',
#  'Speedwash',
#  'Sud Stop Car Wash',
#  'Ace Auto Wash',
#  'BlueBird Express Car Wash',
#  'Dream Clean Car Wash',
#  'H2Go Car Wash',
#  'Pony Express Carwash',
#  'Washtopia Car Wash',
#  'American Pride Xpress Carwash',
#  'Canton Car Wash',
#  'Endless Clean Car Wash',
#  'Mr. Sparkle Car Wash',
#  'Mr. Splash Car Wash',
#  "Pete's Express Car Wash",
#  'RaceWash',
#  'Screaming Eagle  Express Car Wash',
#  'Shur-Kleen Car Wash',
#  'Spin Car Wash',
#  'Supershine Xpress Carwash',
#  '5 Minute Express Car Wash',
#  'Cadillac Express Car Wash',
#  'Fast Freddy�s Car Wash',
#  'FullSpeed Automotive',
#  'Magic Brush Car Wash',
#  'Soapy Noble Car Wash',
#  'Waves Express Car Wash',
#  'Four Seasons Car Wash']

# %%
import re

def normalize_name(name):
    """
    Normalizes a company name through a simplified process:
    1. Converts to lowercase.
    2. Cleans internal "noise" characters (e.g., ®, ™, apostrophes), preserving spaces.
    3. Normalizes whitespace (multiple spaces/tabs to single space, trims).
    4. Removes a predefined list of common trailing phrases from the end.
    5. Finally, removes all remaining non-alphanumeric characters (i.e., spaces) for a compact key.
    """
    if not isinstance(name, str) or not name.strip():  # Handle None, non-string, empty or whitespace-only strings
        return ''

    name_lower = name.lower()

    # Clean internal "noise" characters (non-alphanumeric, non-space)
    # This removes symbols like ®, ™, ', ' etc., but keeps spaces.
    semi_cleaned = re.sub(r"[^a-z0-9\s]", '', name_lower)

    # Normalize whitespace (multiple spaces/tabs to single space, trim)
    semi_cleaned_normalized_space = ' '.join(semi_cleaned.split())

    # Remove known trailing suffixes.
    # Order by length (descending) for correct matching of overlapping/sub-phrases.
    trailing_phrases_to_remove = [
        "car wash",
        "carwash",
        "express car wash",
        "express carwash",    
        "xpress car wash",
        "xpress carwash",
        "auto wash"  
        "express wash"
        "xpress wash"
        "car washes"            
    ]
    trailing_phrases_to_remove.sort(key=len, reverse=True)  # Important: longest match first

    final_name = semi_cleaned_normalized_space
    for phrase in trailing_phrases_to_remove:
        if final_name.endswith(phrase):
            # Remove the phrase and strip any leading/trailing whitespace from the remainder
            final_name = final_name[:-len(phrase)].strip()
            # After removing a major suffix, assume the remainder is the core brand.
            # Stop further suffix stripping for this name.
            break
    
    # Final normalization - remove all remaining non-alphanumeric (i.e., spaces)
    # This collapses multiple word parts into a single string, e.g., "tidal wave" -> "tidalwave".
    normalized = re.sub(r'[^a-z0-9]', '', final_name)
    
    return normalized

# %%
def build_normalized_name_database(company_names_list):
    """
    Normalizes a list of company names and builds a lookup database.
    
    Args:
        company_names_list (list): A list of company names as strings.
        
    Returns:
        tuple: A tuple containing (set of normalized names, dict mapping normalized to original names).
    """
    normalized_set = set()
    normalized_to_original_map = {}

    for original_name in company_names_list:
        if not isinstance(original_name, str) or not original_name.strip():
            continue
            
        normalized = normalize_name(original_name)
        if normalized:
            normalized_set.add(normalized)
            if normalized not in normalized_to_original_map:
                normalized_to_original_map[normalized] = original_name

    return normalized_set, normalized_to_original_map

# %%
build_normalized_name_database(a[:176])
# Out:
# ({'5minute',
#   '7flags',
#   'aceautowash',
#   'allamerican',
#   'americanpride',
#   'autobell',
#   'autospacarwashwa',
#   'autospala',
#   'bennys',
#   'bigdans',
#   'bigpeach',
#   'bliss',
#   'bluebird',
#   'bluepenguin',
#   'bluewave',
#   'breezethru',
#   'briteworxcarwashery',
#   'brownbear',
#   'bubbledown',
#   'buddybear',
#   'cadillac',
#   'caliber',
#   'canton',
#   'carnationautospa',
#   'carriagehouse',
#   'carspa',
#   'champion',
#   'charlies',
#   'cheetahcleanautowash',
#   'cleansweep',
#   'clearwaterexpresswash',
#   'clearwave',
#   'cloud10smartwash',
#   'club',
#   'crew',
#   'deltasonic',
#   'dirtydogs',
#   'dreamclean',
#   'driven',
#   'driveshine',
#   'duckys',
#   'edge',
#   'el',
#   'elephantsuper',
#   'endlessclean',
#   'everclean',
#   'expresswashconcepts',
#   'fabulousfreddys',
#   'fast5',
#   'fasteddiescarwashoilchange',
#   'fastfreddys',
#   'fastsplash',
#   'flagstop',
#   'flash',
#   'fourseasons',
#   'francissons',
#   'fullers',
#   'fullspeedautomotive',
#   'gasnwash',
#   'gate',
#   'glide',
#   'go',
#   'goldennozzle',
#   'groove',
#   'h2go',
#   'haffners',
#   'hang10',
#   'hoffman',
#   'hurricaneexpresswash',
#   'ishineexpresscarwashdetail',
#   'jacksons',
#   'jaxkarwash',
#   'jetsplash',
#   'kaady',
#   'luv',
#   'mach1expresswash',
#   'magicbrush',
#   'mammothholdingsllc',
#   'metro',
#   'mightywash',
#   'mikes',
#   'mister',
#   'modwash',
#   'mrclean',
#   'mrmagic',
#   'mrsparkle',
#   'mrsplash',
#   'mrwash',
#   'oceanblue',
#   'pelicanpointe',
#   'petes',
#   'pony',
#   'prestige',
#   'quicknclean',
#   'quickquack',
#   'racewash',
#   'raceway',
#   'radiant',
#   'raindrop',
#   'rainforestcarwashoilchange',
#   'redcarpet',
#   'richs',
#   'ridistores',
#   'rocket',
#   'rocketfast',
#   'rockymountain',
#   'ronnys',
#   'sams',
#   'scenicsuds',
#   'screamingeagle',
#   'scrubadub',
#   'scrubadubautowashcenters',
#   'scrubbys',
#   'sgtcleans',
#   'shammyshinecarwashes',
#   'shinetimesuperwash',
#   'shinyshell',
#   'shurkleen',
#   'skweekykleen',
#   'snapclean',
#   'soapyjoes',
#   'soapynoble',
#   'sparklingimage',
#   'speedwash',
#   'speedystop',
#   'spin',
#   'splash',
#   'splashcarwashoilchange',
#   'splashineco',
#   'spotlessbrands',
#   'sudsdeluxe',
#   'sudstop',
#   'summitwashholdings',
#   'superclean',
#   'supershine',
#   'superstar',
#   'surfthru',
#   'taggngo',
#   'team',
#   'terribleherbst',
#   'theautospa',
#   'thewashtub',
#   'thoroughbredexpressautowash',
#   'tidalwaveautospa',
#   'timetoshine',
#   'tommys',
#   'trademark',
#   'trueblue',
#   'trushine',
#   'tsunamiexpress',
#   'ultracleanexpress',
#   'valetautowash',
#   'velocity',
#   'washfactory',
#   'washguys',
#   'washmancarwashes',
#   'washmasters',
#   'washnroll',
#   'washrite',
#   'washtopia',
#   'washu',
#   'washville',
#   'washx',
#   'watershed',
#   'waterway',
#   'waves',
#   'wetgo',
#   'whistle',
#   'whitehorseautowash',
#   'whitewater',
#   'woodieswashshack',
#   'wow',
#   'xtremeautowash',
#   'zaxautowash'},
#  {'whistle': 'Whistle Express Car Wash',
#   'mister': 'Mister Car Wash',
#   'tidalwaveautospa': 'Tidal Wave Auto Spa',
#   'quickquack': 'Quick Quack Express Car Wash',
#   'club': 'Club Car Wash',
#   'tommys': 'Tommy�s Express Car Wash',
#   'spotlessbrands': 'Spotless Brands',
#   'go': 'GO Car Wash',
#   'mammothholdingsllc': 'Mammoth Holdings LLC',
#   'whitewater': 'WhiteWater Express Car Wash',
#   'modwash': 'ModWash',
#   'expresswashconcepts': 'Express Wash Concepts',
#   'superstar': 'Super Star Car Wash',
#   'autobell': 'Autobell Car Wash',
#   'luv': 'LUV Car Wash',
#   'summitwashholdings': 'Summit Wash Holdings',
#   'trueblue': 'True Blue Car Wash',
#   'splash': 'Splash Car Wash',
#   'caliber': 'Caliber Car Wash',
#   'bluewave': 'BlueWave Express Car Wash',
#   'el': 'El Car Wash',
#   'splashineco': 'Splash in ECO Car Wash',
#   'goldennozzle': 'Golden Nozzle Car Wash',
#   'champion': 'Champion Xpress Carwash',
#   'crew': 'Crew Carwash',
#   'sams': "Sam's Xpress Car Wash",
#   'jaxkarwash': 'Jax Kar Wash',
#   'terribleherbst': 'Terrible Herbst',
#   'bigdans': "Big Dan's Car Wash",
#   'mrclean': 'Mr. Clean Car Wash',
#   'raceway': 'Raceway Express Car Wash',
#   'sparklingimage': 'Sparkling Image Car Wash',
#   'washnroll': "Wash N' Roll",
#   'richs': "Rich's Car Wash",
#   'mikes': "Mike's Car Wash",
#   'surfthru': 'Surf Thru Express Car Wash',
#   'watershed': 'Watershed Carwash',
#   'wetgo': 'WetGo Car Wash',
#   'deltasonic': 'Delta Sonic',
#   'thewashtub': 'The Wash Tub',
#   'gasnwash': 'Gas N Wash',
#   'hurricaneexpresswash': 'Hurricane Express Wash',
#   'brownbear': 'Brown Bear Car Wash',
#   'waterway': 'Waterway Carwash',
#   'hoffman': 'Hoffman Car Wash',
#   'quicknclean': 'Quick N Clean',
#   'clearwaterexpresswash': 'ClearWater Express Wash',
#   'thoroughbredexpressautowash': 'Thoroughbred Express Auto Wash',
#   'trademark': 'Trademark Car Wash',
#   'rocket': 'Rocket Carwash',
#   'soapyjoes': 'Soapy Joe�s Car Wash',
#   'washmasters': 'Wash Masters Car Wash',
#   'washville': 'Washville Car Wash',
#   'fast5': 'Fast 5 Xpress Car Wash',
#   'glide': 'Glide XPRESS Car Wash',
#   'prestige': 'Prestige Car Wash',
#   'ultracleanexpress': 'Ultra Clean Express',
#   'flagstop': 'Flagstop Car Wash',
#   'mightywash': 'Mighty Wash',
#   'mrmagic': 'Mr. Magic Car Wash',
#   'scrubadubautowashcenters': 'ScrubaDub Auto Wash Centers',
#   'splashcarwashoilchange': 'Splash Car Wash & Oil Change',
#   'woodieswashshack': "Woodie's Wash Shack",
#   'wow': 'WOW Carwash',
#   'carnationautospa': 'Carnation Auto Spa',
#   'dirtydogs': 'Dirty Dog�s Car Wash',
#   'taggngo': 'Tagg-N-Go',
#   'driveshine': 'Drive & Shine Car Wash',
#   'flash': 'Flash Car Wash',
#   'sgtcleans': 'Sgt. Clean�s Car Wash',
#   'trushine': 'TruShine Car Wash',
#   'francissons': 'Francis & Sons Car Wash',
#   'fullers': "Fuller's Car Wash",
#   'shinyshell': 'Shiny Shell Car Wash',
#   'washmancarwashes': 'Washman Car Washes',
#   'bubbledown': 'Bubble Down Car Wash',
#   'elephantsuper': 'Elephant Super Car Wash',
#   'kaady': 'Kaady Car Wash',
#   'ronnys': "Ronny's Car Wash",
#   'bigpeach': 'Big Peach Car Wash',
#   'bliss': 'Bliss Car Wash',
#   'buddybear': 'Buddy Bear Car Wash',
#   'fasteddiescarwashoilchange': "Fast Eddie's Car Wash & Oil Change",
#   'gate': 'Gate Express Car Wash',
#   'zaxautowash': 'Zax Auto Wash',
#   'haffners': "Haffner's",
#   'rainforestcarwashoilchange': 'Rainforest Carwash & Oil Change',
#   'shammyshinecarwashes': 'Shammy Shine Car Washes',
#   'carspa': 'Car Spa',
#   'mach1expresswash': 'Mach-1 Express Wash',
#   'ridistores': 'Ridi Stores',
#   'rockymountain': 'Rocky Mountain Car Wash',
#   'breezethru': 'Breeze Thru Car Wash',
#   'carriagehouse': 'Carriage House Car Wash',
#   'edge': 'EDGE Express Car Wash',
#   'metro': 'Metro Express Car Wash',
#   'pelicanpointe': 'Pelican Pointe Car Wash',
#   'theautospa': 'The Auto Spa',
#   'valetautowash': 'Valet Auto Wash',
#   'allamerican': 'All American Car Wash',
#   'charlies': 'Charlie�s Car Wash',
#   'ishineexpresscarwashdetail': 'iShine Express Car Wash & Detail',
#   'jacksons': 'Jacksons',
#   'speedystop': 'Speedy Stop Car Wash',
#   'team': 'Team Car Wash',
#   'washrite': 'Wash-Rite Express Car Wash',
#   'washu': 'WashU Car Wash',
#   'whitehorseautowash': 'White Horse Auto Wash',
#   'fastsplash': 'Fast Splash Car Wash',
#   'hang10': 'Hang 10 Car Wash',
#   'raindrop': 'Raindrop Car Wash',
#   'rocketfast': 'RocketFast Car Wash',
#   'superclean': 'Super Clean Car Wash',
#   'timetoshine': 'Time To Shine Car Wash',
#   'washx': 'WashX Car Wash',
#   'xtremeautowash': 'Xtreme Auto Wash',
#   '7flags': '7 Flags Car Wash',
#   'cheetahcleanautowash': 'Cheetah Clean Auto Wash',
#   'duckys': "Ducky's Car Wash",
#   'groove': 'Groove Car Wash',
#   'mrwash': 'Mr Wash Car Wash',
#   'redcarpet': 'Red Carpet Car Wash',
#   'scrubadub': 'Scrub-a-Dub',
#   'shinetimesuperwash': 'Shine Time Super Wash',
#   'tsunamiexpress': 'Tsunami Express',
#   'washfactory': 'Wash Factory Car Wash',
#   'bluepenguin': 'Blue Penguin Car Wash',
#   'briteworxcarwashery': 'BriteworX Car Washery',
#   'cleansweep': 'Clean Sweep Car Wash',
#   'cloud10smartwash': 'Cloud 10 Smartwash',
#   'everclean': 'Everclean Car Wash',
#   'scenicsuds': 'Scenic Suds Car Wash',
#   'scrubbys': 'Scrubby�s Car Wash',
#   'skweekykleen': 'Skweeky Kleen Car Wash',
#   'speedwash': 'SpeedWash Car Wash',
#   'sudsdeluxe': 'Suds Deluxe Car Wash',
#   'washguys': 'WashGuys Car Wash',
#   'autospacarwashwa': 'Auto Spa Car Wash (WA)',
#   'bennys': 'Benny�s Car Wash',
#   'driven': 'Driven Car Wash',
#   'fabulousfreddys': 'Fabulous Freddy�s Car Wash',
#   'jetsplash': 'Jet Splash Car Wash',
#   'radiant': 'Radiant Express Car Wash',
#   'velocity': 'Velocity Car Wash',
#   'autospala': 'Auto Spa LA',
#   'clearwave': 'Clearwave Car Wash',
#   'oceanblue': 'Ocean Blue Car Wash',
#   'snapclean': 'Snap Clean Car Wash',
#   'sudstop': 'Sud Stop Car Wash',
#   'aceautowash': 'Ace Auto Wash',
#   'bluebird': 'BlueBird Express Car Wash',
#   'dreamclean': 'Dream Clean Car Wash',
#   'h2go': 'H2Go Car Wash',
#   'pony': 'Pony Express Carwash',
#   'washtopia': 'Washtopia Car Wash',
#   'americanpride': 'American Pride Xpress Carwash',
#   'canton': 'Canton Car Wash',
#   'endlessclean': 'Endless Clean Car Wash',
#   'mrsparkle': 'Mr. Sparkle Car Wash',
#   'mrsplash': 'Mr. Splash Car Wash',
#   'petes': "Pete's Express Car Wash",
#   'racewash': 'RaceWash',
#   'screamingeagle': 'Screaming Eagle  Express Car Wash',
#   'shurkleen': 'Shur-Kleen Car Wash',
#   'spin': 'Spin Car Wash',
#   'supershine': 'Supershine Xpress Carwash',
#   '5minute': '5 Minute Express Car Wash',
#   'cadillac': 'Cadillac Express Car Wash',
#   'fastfreddys': 'Fast Freddy�s Car Wash',
#   'fullspeedautomotive': 'FullSpeed Automotive',
#   'magicbrush': 'Magic Brush Car Wash',
#   'soapynoble': 'Soapy Noble Car Wash',
#   'waves': 'Waves Express Car Wash',
#   'fourseasons': 'Four Seasons Car Wash'})
